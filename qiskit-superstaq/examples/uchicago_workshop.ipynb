# %% [markdown]
# ## CQE/UCQ Workshop

# %% [markdown]
# Super.tech focuses on quantum benchmarking and optimizations of quantum applications via cross-layer-optimization.
# This notebook is going to be focused on an example of cross-layer-optimization.
#
# We deliver our software via a server that users can access given a token. Anyone can sign up for a $5 free trial for Superstaq. Users can access our API via our clients; `qiksit-superstaq` and `cirq-superstaq`. They can also build their own client. Our agenda for today will consist of a tour of the Superstaq API, qiskit-superstaq, and general Superstaq. We will also walk through an example of cross layer optimiation by reading and executing code from the [Faster and More Reliable Quantum SWAPs via Native Gates](https://arxiv.org/abs/2109.13199) paper that got us a top ranking submision for the [IBM SWAP challenge](https://research.ibm.com/blog/quantum-open-science-prize-winners). After that, we will work on Github issues for qiskit-superstaq, cirq-superstaq and general-superstaq to demonstrate the development workflow of Superstaq.

# %% [markdown]
# ## Optimizing the SWAP gate

# %%
from typing import Tuple
import numpy as np
import qiskit

from qiskit_superstaq.superstaq_provider import SuperstaqProvider

# %%
# Provide your api key to the using the "api_key" argument if
# SUPERSTAQ_API_KEY environment variable is not set.
superstaq_provider = SuperstaqProvider()

# %%
# qiskit.IBMQ.enable_account("IBMQ token")
qiskit.IBMQ.load_account()
# Out:
# <AccountProvider for IBMQ(hub='ibm-q', group='open', project='main')>

# %%
for provider in qiskit.IBMQ.providers():
    print(provider.backends())
# Out:
# [<IBMQSimulator('ibmq_qasm_simulator') from IBMQ(hub='ibm-q', group='open', project='main')>, <IBMQBackend('ibmq_lima') from IBMQ(hub='ibm-q', group='open', project='main')>, <IBMQBackend('ibmq_belem') from IBMQ(hub='ibm-q', group='open', project='main')>, <IBMQBackend('ibmq_quito') from IBMQ(hub='ibm-q', group='open', project='main')>, <IBMQSimulator('simulator_statevector') from IBMQ(hub='ibm-q', group='open', project='main')>, <IBMQSimulator('simulator_mps') from IBMQ(hub='ibm-q', group='open', project='main')>, <IBMQSimulator('simulator_extended_stabilizer') from IBMQ(hub='ibm-q', group='open', project='main')>, <IBMQSimulator('simulator_stabilizer') from IBMQ(hub='ibm-q', group='open', project='main')>, <IBMQBackend('ibmq_manila') from IBMQ(hub='ibm-q', group='open', project='main')>, <IBMQBackend('ibm_nairobi') from IBMQ(hub='ibm-q', group='open', project='main')>, <IBMQBackend('ibm_oslo') from IBMQ(hub='ibm-q', group='open', project='main')>]
# [<IBMQSimulator('ibmq_qasm_simulator') from IBMQ(hub='ibm-q-startup', group='super-tech-labs', project='default')>, <IBMQBackend('ibmq_lima') from IBMQ(hub='ibm-q-startup', group='super-tech-labs', project='default')>, <IBMQBackend('ibmq_belem') from IBMQ(hub='ibm-q-startup', group='super-tech-labs', project='default')>, <IBMQBackend('ibmq_quito') from IBMQ(hub='ibm-q-startup', group='super-tech-labs', project='default')>, <IBMQBackend('ibmq_jakarta') from IBMQ(hub='ibm-q-startup', group='super-tech-labs', project='default')>, <IBMQBackend('ibmq_manila') from IBMQ(hub='ibm-q-startup', group='super-tech-labs', project='default')>, <IBMQBackend('ibm_lagos') from IBMQ(hub='ibm-q-startup', group='super-tech-labs', project='default')>]
# [<IBMQBackend('ibmq_belem') from IBMQ(hub='ibm-q-startup', group='super-tech-labs', project='reservations')>, <IBMQBackend('ibmq_jakarta') from IBMQ(hub='ibm-q-startup', group='super-tech-labs', project='reservations')>, <IBMQBackend('ibm_lagos') from IBMQ(hub='ibm-q-startup', group='super-tech-labs', project='reservations')>, <IBMQBackend('ibm_nairobi') from IBMQ(hub='ibm-q-startup', group='super-tech-labs', project='reservations')>, <IBMQBackend('ibm_perth') from IBMQ(hub='ibm-q-startup', group='super-tech-labs', project='reservations')>, <IBMQBackend('ibm_oslo') from IBMQ(hub='ibm-q-startup', group='super-tech-labs', project='reservations')>]

# %%
ibmq_provider = qiskit.IBMQ.providers()[2]

# %%
print(ibmq_provider.backends())
# Out:
# [<IBMQBackend('ibmq_belem') from IBMQ(hub='ibm-q-startup', group='super-tech-labs', project='reservations')>, <IBMQBackend('ibmq_jakarta') from IBMQ(hub='ibm-q-startup', group='super-tech-labs', project='reservations')>, <IBMQBackend('ibm_lagos') from IBMQ(hub='ibm-q-startup', group='super-tech-labs', project='reservations')>, <IBMQBackend('ibm_nairobi') from IBMQ(hub='ibm-q-startup', group='super-tech-labs', project='reservations')>, <IBMQBackend('ibm_perth') from IBMQ(hub='ibm-q-startup', group='super-tech-labs', project='reservations')>, <IBMQBackend('ibm_oslo') from IBMQ(hub='ibm-q-startup', group='super-tech-labs', project='reservations')>]

# %%
backend = ibmq_provider.get_backend("ibm_lagos")

# %%
qc = qiskit.QuantumCircuit(2, 2)
qc.swap(0, 1)
qc.measure([0, 1], [0, 1])
print(qc)
# Out:
#         ┌─┐
# q_0: ─X─┤M├───
#       │ └╥┘┌─┐
# q_1: ─X──╫─┤M├
#          ║ └╥┘
# c: 2/════╩══╩═
#          0  1

# %%
transpiled_qc = qiskit.transpile(qc, backend)

# %%
print(transpiled_qc)
# Out:
#                     ┌───┐     ┌─┐
#       q_0 -> 0 ──■──┤ X ├──■──┤M├───
#                ┌─┴─┐└─┬─┘┌─┴─┐└╥┘┌─┐
#       q_1 -> 1 ┤ X ├──■──┤ X ├─╫─┤M├
#                └───┘     └───┘ ║ └╥┘
# ancilla_0 -> 2 ────────────────╫──╫─
#                                ║  ║
# ancilla_1 -> 3 ────────────────╫──╫─
#                                ║  ║
# ancilla_2 -> 4 ────────────────╫──╫─
#                                ║  ║
# ancilla_3 -> 5 ────────────────╫──╫─
#                                ║  ║
# ancilla_4 -> 6 ────────────────╫──╫─
#                                ║  ║
#           c: 2/════════════════╩══╩═
#                                0  1

# %%
pulse_schedule_standard = qiskit.schedule(transpiled_qc, backend)

# %%
pulse_schedule_standard.draw()

# %%
pulse_schedule_optimized = superstaq_provider.ibmq_compile(qc, target="ibmq_jakarta_qpu")
pulse_schedule_optimized.draw()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [20], in <cell line: 2>()
#       1 pulse_schedule_optimized = superstaq_provider.ibmq_compile(qc, target="ibmq_jakarta_qpu")
# ----> 2 pulse_schedule_optimized.draw()
#
# AttributeError: 'CompilerOutput' object has no attribute 'draw'

# %%
job1 = qiskit.execute(pulse_schedule_standard, shots=4000, backend=backend)

# %%
job2 = qiskit.execute(pulse_schedule_optimized, shots=4000, backend=backend)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [21], in <cell line: 1>()
# ----> 1 job2 = qiskit.execute(pulse_schedule_optimized, shots=4000, backend=backend)
#
# File ~/coldquanta/venv_qiskit_superstaq/lib/python3.8/site-packages/qiskit/execute_function.py:297, in execute(experiments, backend, basis_gates, coupling_map, backend_properties, initial_layout, seed_transpiler, optimization_level, pass_manager, qobj_id, qobj_header, shots, memory, max_credits, seed_simulator, default_qubit_los, default_meas_los, qubit_lo_range, meas_lo_range, schedule_los, meas_level, meas_return, memory_slots, memory_slot_size, rep_time, rep_delay, parameter_binds, schedule_circuit, inst_map, meas_map, scheduling_method, init_qubits, **run_config)
#     294     experiments = pass_manager.run(experiments)
#     295 else:
#     296     # transpiling the circuits using given transpile options
# --> 297     experiments = transpile(
#     298         experiments,
#     299         basis_gates=basis_gates,
#     300         coupling_map=coupling_map,
#     301         backend_properties=backend_properties,
#     302         initial_layout=initial_layout,
#     303         seed_transpiler=seed_transpiler,
#     304         optimization_level=optimization_level,
#     305         backend=backend,
#     306     )
#     308 if schedule_circuit:
#     309     experiments = schedule(
#     310         circuits=experiments,
#     311         backend=backend,
#    (...)
#     314         method=scheduling_method,
#     315     )
#
# File ~/coldquanta/venv_qiskit_superstaq/lib/python3.8/site-packages/qiskit/compiler/transpiler.py:276, in transpile(circuits, backend, basis_gates, inst_map, coupling_map, backend_properties, initial_layout, layout_method, routing_method, translation_method, scheduling_method, instruction_durations, dt, approximation_degree, timing_constraints, seed_transpiler, optimization_level, callback, output_name, unitary_synthesis_method, unitary_synthesis_plugin_config, target)
#     269     warnings.warn(
#     270         "When scheduling circuits without backend,"
#     271         " 'instruction_durations' should be usually provided.",
#     272         UserWarning,
#     273     )
#     275 # Get transpile_args to configure the circuit transpilation job(s)
# --> 276 transpile_args = _parse_transpile_args(
#     277     circuits,
#     278     backend,
#     279     basis_gates,
#     280     inst_map,
#     281     coupling_map,
#     282     backend_properties,
#     283     initial_layout,
#     284     layout_method,
#     285     routing_method,
#     286     translation_method,
#     287     scheduling_method,
#     288     instruction_durations,
#     289     dt,
#     290     approximation_degree,
#     291     seed_transpiler,
#     292     optimization_level,
#     293     callback,
#     294     output_name,
#     295     timing_constraints,
#     296     unitary_synthesis_method,
#     297     unitary_synthesis_plugin_config,
#     298     target,
#     299 )
#     301 _check_circuits_coupling_map(circuits, transpile_args, backend)
#     303 # Transpile circuits in parallel
#
# File ~/coldquanta/venv_qiskit_superstaq/lib/python3.8/site-packages/qiskit/compiler/transpiler.py:540, in _parse_transpile_args(circuits, backend, basis_gates, inst_map, coupling_map, backend_properties, initial_layout, layout_method, routing_method, translation_method, scheduling_method, instruction_durations, dt, approximation_degree, seed_transpiler, optimization_level, callback, output_name, timing_constraints, unitary_synthesis_method, unitary_synthesis_plugin_config, target)
#     538 seed_transpiler = _parse_seed_transpiler(seed_transpiler, num_circuits)
#     539 optimization_level = _parse_optimization_level(optimization_level, num_circuits)
# --> 540 output_name = _parse_output_name(output_name, circuits)
#     541 callback = _parse_callback(callback, num_circuits)
#     542 durations = _parse_instruction_durations(backend, instruction_durations, dt, circuits)
#
# File ~/coldquanta/venv_qiskit_superstaq/lib/python3.8/site-packages/qiskit/compiler/transpiler.py:1065, in _parse_output_name(output_name, circuits)
#    1060         raise TranspilerError(
#    1061             "The parameter output_name should be a string or a"
#    1062             "list of strings: %s was used." % type(output_name)
#    1063         )
#    1064 else:
# -> 1065     return [circuit.name for circuit in circuits]
#
# File ~/coldquanta/venv_qiskit_superstaq/lib/python3.8/site-packages/qiskit/compiler/transpiler.py:1065, in <listcomp>(.0)
#    1060         raise TranspilerError(
#    1061             "The parameter output_name should be a string or a"
#    1062             "list of strings: %s was used." % type(output_name)
#    1063         )
#    1064 else:
# -> 1065     return [circuit.name for circuit in circuits]
#
# AttributeError: 'CompilerOutput' object has no attribute 'name'

# %%
job1.status()
# Out:
# <JobStatus.DONE: 'job has successfully run'>

# %%
job2.status()
# Out:
# <JobStatus.DONE: 'job has successfully run'>

# %%
job1.result().get_counts()
# Out:
# {'00': 3489, '01': 141, '10': 220, '11': 150}

# %%
job2.result().get_counts()
# Out:
# {'00': 3501, '01': 174, '10': 274, '11': 51}

# %% [markdown]
# ## The following code is how we construct the optimized pulse schedule

# %%
ism = backend.defaults().instruction_schedule_map

# %%
def _is_fast_cx_orientation(i: int, j: int) -> bool:
    """Returns whether CX(i, j) is faster than CX(j, i).

    While both gates are possible on any connected qubit pairs, one orientation is faster
    than the other since the cross-resonance is directional.
    """
    return ism.get("cx", qubits=[i, j]).duration < ism.get("cx", qubits=[j, i]).duration

# %%
def _get_echoed_cr_schedule(i: int, j: int, *, polarity: str = "+-") -> qiskit.pulse.Schedule:
    """Applies an echoed cross resonance in either the +- or -+ polarity.

    This operation is not merely a CR90P/N; it also has a side effect of an X on the control.
    """
    assert polarity in ["+-", "-+"]
    CR45P_schedule, CR45N_schedule = _get_cr_45p_and_45n(i, j)

    schedule = CR45P_schedule if polarity == "+-" else CR45N_schedule
    schedule |= ism.get("x", qubits=[i]) << schedule.duration
    schedule |= (CR45N_schedule if polarity == "+-" else CR45P_schedule) << schedule.duration
    return schedule

# %%
def _get_cr_45p_and_45n(i: int, j: int) -> Tuple[qiskit.pulse.Schedule, qiskit.pulse.Schedule]:
    """Extracts the CR(+45) and CR(-45) pulse schedules from the schedule for CX(i, j).
    If the CR's are oriented in the opposite direction, returns None.
    """
    if not _is_fast_cx_orientation(i, j):
        return None

    cx_schedule = ism.get("cx", qubits=[i, j])
    cr_start_index = -1

    for i, (_, instruction) in enumerate(cx_schedule.instructions):
        # the Cross-Resonance within the CNOT starts with a GaussianSquare Play instruction
        if isinstance(instruction, qiskit.pulse.Play):
            if isinstance(instruction.pulse, qiskit.pulse.library.parametric_pulses.GaussianSquare):
                cr_start_index = i
                break

    assert cr_start_index != -1, "did not find the start of CR"

    cr_instructions = cx_schedule.instructions[cr_start_index:]
    assert len(cr_instructions) == 5, f"{cr_instructions} should have 5 instructions"

    # first two are CR(+45), last two are CR(-45)
    CR45P_schedule = cr_instructions[0][1] + cr_instructions[1][1]
    CR45N_schedule = cr_instructions[3][1] + cr_instructions[4][1]

    return CR45P_schedule, CR45N_schedule

# %%
def get_optimized_swap_pulse(i: int, j: int) -> qiskit.pulse.Schedule:
    """Returns our optimized SWAP pulse schedule."""

    # SWAP(i, j) = SWAP(j, i), so we pick the direction that is better aligned
    # with the native orientation of the pre-calibrated Cross-Resonance pulses
    if _get_cr_45p_and_45n(i, j) is None:
        j, i = i, j

    # The schedule below describes our Optimized SWAP pulse schedule
    # See Optimized_SWAP.pdf for details and a circuit-level description (Fig 14 in Appendix)
    # Since we re-use precalibrated pulses, our method has zero calibration overhead

    schedule = qiskit.pulse.Schedule(name="Optimized SWAP Schedule")
    schedule |= ism.get("rz", qubits=[i], P0=np.pi / 2) << schedule.duration
    schedule |= _get_echoed_cr_schedule(i, j, polarity="-+") << schedule.duration

    schedule |= ism.get("rz", qubits=[i], P0=np.pi / 2) << schedule.duration
    schedule |= ism.get("rz", qubits=[j], P0=-np.pi / 2) << schedule.duration
    schedule |= ism.get("sx", qubits=[i]) + ism.get("sx", qubits=[j]) << schedule.duration
    schedule |= ism.get("rz", qubits=[i], P0=np.pi) << schedule.duration

    schedule |= _get_echoed_cr_schedule(i, j, polarity="+-") << schedule.duration

    schedule |= ism.get("rz", qubits=[i], P0=-np.pi / 2) << schedule.duration
    schedule |= ism.get("rz", qubits=[j], P0=-np.pi / 2) << schedule.duration
    schedule |= ism.get("sx", qubits=[i]) << schedule.duration
    schedule |= ism.get("rz", qubits=[i], P0=np.pi) << schedule.duration

    schedule |= _get_echoed_cr_schedule(i, j, polarity="+-") << schedule.duration

    return schedule

# %%
manual_schedule = optimized_swap_schedule = get_optimized_swap_pulse(1, 0)

# %%
manual_schedule.draw()
